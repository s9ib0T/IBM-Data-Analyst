# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping**

# %% [markdown]
# ## Objectives

# %% [markdown]
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site

# %%
# Requirements
import pandas as pd
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# Get webpage data

# %%
df = pd.read_html(url, header=0)[0]
df.set_index(df.columns[0], inplace=True)
df.head()
# Out:
#        Language                    Created By Average Annual Salary  \
# No.
# 1        Python              Guido van Rossum              $114,383
# 2          Java                 James Gosling              $101,013
# 3             R  Robert Gentleman, Ross Ihaka               $92,037
# 4    Javascript                      Netscape              $110,981
# 5         Swift                         Apple              $130,801
#
#     Learning Difficulty
# No.
# 1                  Easy
# 2                  Easy
# 3                  Hard
# 4                  Easy
# 5                  Easy

# %% [markdown]
# The data needed is the **name of the programming language** and **average annual salary**

# %%
df = df[['Language', 'Average Annual Salary']]
df.head()
# Out:
#        Language Average Annual Salary
# No.
# 1        Python              $114,383
# 2          Java              $101,013
# 3             R               $92,037
# 4    Javascript              $110,981
# 5         Swift              $130,801

# %% [markdown]
# #### Save the data into a file named *popular-languages.csv*

# %%
df.to_csv('popular-languages.csv', index=False)
